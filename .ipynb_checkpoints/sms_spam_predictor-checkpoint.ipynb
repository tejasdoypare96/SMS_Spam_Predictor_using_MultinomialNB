# %% [markdown]
# ## Importig libraries

# %%
import pandas as pd
import numpy as np
import nltk
import seaborn as sns

# %% [markdown]
# ## dataset

# %%
df = pd.read_csv('spam.csv', encoding='ISO-8859-1')

# %%
df.head
# Out:
# <bound method NDFrame.head of         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# ...

# %%
df.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
df = df[['v1', 'v2']]

# %%
df.shape
# Out:
# (5572, 2)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ### Renaming Columns

# %%
df =  df.rename(columns = {'v1':'class_label','v2':'message'})

# %%
df.head()
# Out:
#   class_label                                            message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ### Encoding

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# %%
df['class_label'] = label_encoder.fit_transform(df['class_label'])

# %%
df.head()
# Out:
#    class_label                                            message
# 0            0  Go until jurong point, crazy.. Available only ...
# 1            0                      Ok lar... Joking wif u oni...
# 2            1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3            0  U dun say so early hor... U c already then say...
# 4            0  Nah I don't think he goes to usf, he lives aro...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (8, 6))

# %%
df.head
# Out:
# <bound method NDFrame.head of       class_label                                            message
# 0               0  Go until jurong point, crazy.. Available only ...
# 1               0                      Ok lar... Joking wif u oni...
# 2               1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3               0  U dun say so early hor... U c already then say...
# 4               0  Nah I don't think he goes to usf, he lives aro...
# ...           ...                                                ...
# 5567            1  This is the 2nd time we have tried 2 contact u...
# 5568            0              Will Ì_ b going to esplanade fr home?
# 5569            0  Pity, * was in mood for that. So...any other s...
# 5570            0  The guy did some bitching but I acted like i'd...
# 5571            0                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]>

# %%
df['class_label'].value_counts()
# Out:
# class_label
# 0    4516
# 1     653
# Name: count, dtype: int64

# %% [markdown]
# ## Visualization

# %%
plt.pie(df['class_label'].value_counts(), labels = ['ham', 'spam'], autopct= '%0.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d9fb769940>,
# ...
#  [Text(-1.0144997251399075, 0.4251944351600247, 'ham'),
#   Text(1.014499764949479, -0.4251943401757036, 'spam')],
#  [Text(-0.5533634864399495, 0.23192423736001344, '87.37'),
#   Text(0.5533635081542612, -0.23192418555038377, '12.63')])

# %%
plt.pie(df['class_label'].value_counts(), labels = ['ham', 'spam'], autopct= '%0.2f')
plt.show()

# %%
# Data is Imbalanced

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['num_character'] = df['message'].apply(len)

# %%
df.head()
# Out:
#    class_label                                            message  \
# 0            0  Go until jurong point, crazy.. Available only ...
# 1            0                      Ok lar... Joking wif u oni...
# 2            1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3            0  U dun say so early hor... U c already then say...
# 4            0  Nah I don't think he goes to usf, he lives aro...
#
#    num_character
# 0            111
# 1             29
# 2            155
# 3             49
# 4             61

# %%
## num of words
df['num_words'] = df['message'].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    class_label                                            message  \
# 0            0  Go until jurong point, crazy.. Available only ...
# 1            0                      Ok lar... Joking wif u oni...
# 2            1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3            0  U dun say so early hor... U c already then say...
# 4            0  Nah I don't think he goes to usf, he lives aro...
#
#    num_character  num_words
# 0            111         24
# 1             29          8
# 2            155         37
# 3             49         13
# 4             61         15

# %%
# no of sentences
df['num_sentences']=df['message'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    class_label                                            message  \
# 0            0  Go until jurong point, crazy.. Available only ...
# 1            0                      Ok lar... Joking wif u oni...
# 2            1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3            0  U dun say so early hor... U c already then say...
# 4            0  Nah I don't think he goes to usf, he lives aro...
#
#    num_character  num_words  num_sentences
# 0            111         24              2
# 1             29          8              2
# 2            155         37              2
# 3             49         13              1
# 4             61         15              1

# %%
df.describe()
# Out:
#        class_label  num_character    num_words  num_sentences
# count  5169.000000    5169.000000  5169.000000    5169.000000
# mean      0.126330      78.977945    18.455794       1.965564
# std       0.332253      58.236293    13.324758       1.448541
# min       0.000000       2.000000     1.000000       1.000000
# 25%       0.000000      36.000000     9.000000       1.000000
# 50%       0.000000      60.000000    15.000000       1.000000
# 75%       0.000000     117.000000    26.000000       2.000000
# max       1.000000     910.000000   220.000000      38.000000

# %%
sns.histplot(df[df['class_label'] == 0]['num_character'])
sns.histplot(df[df['class_label'] == 1]['num_character'], color = 'red')
# Out:
# <Axes: xlabel='num_character', ylabel='Count'>

# %%
sns.histplot(df[df['class_label'] == 0]['num_words'])
sns.histplot(df[df['class_label'] == 1]['num_words'], color = 'red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df, hue = 'class_label')

# %%
sns.heatmap(df[['num_words', 'num_character', 'num_sentences', 'class_label']].corr(), annot= True)
# Out:
# <Axes: >

# %% [markdown]
# ## Data Preprocesssing

# %%
# Lower case
# Tokenization
# Removing special characters
# Removing stop words and punctuation
# Stemming

# %%
nltk.download('punkit')
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading punkit: Package 'punkit' not found in index
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df.head()
# Out:
#    class_label                                            message  \
# 0            0  Go until jurong point, crazy.. Available only ...
# 1            0                      Ok lar... Joking wif u oni...
# 2            1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3            0  U dun say so early hor... U c already then say...
# 4            0  Nah I don't think he goes to usf, he lives aro...
#
#    num_character  num_words  num_sentences
# 0            111         24              2
# 1             29          8              2
# 2            155         37              2
# 3             49         13              1
# 4             61         15              1

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def DataPreprocessing(data):
    data = data.lower()
    data = word_tokenize(data)
    y = []
    for i in data:
        if i.isalnum():
            y.append(i)

    data = y[:]
    y.clear()
    stop_words = set(stopwords.words('english'))

    for w in data:
        if w not in stop_words:
            y.append(w)

    data = y[:]
    y.clear()

    for i in data:
        y.append(ps.stem(i))


    return " ".join(y)

# %%
df['transformed_text'] = df['message'].apply(DataPreprocessing)

# %%
df.head()
# Out:
#    class_label                                            message  \
# 0            0  Go until jurong point, crazy.. Available only ...
# 1            0                      Ok lar... Joking wif u oni...
# 2            1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3            0  U dun say so early hor... U c already then say...
# 4            0  Nah I don't think he goes to usf, he lives aro...
#
#    num_character  num_words  num_sentences  \
# 0            111         24              2
# 1             29          8              2
# 2            155         37              2
# 3             49         13              1
# 4             61         15              1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# ...

# %%
## making word cloud
from wordcloud import WordCloud
wc = WordCloud(width = 500, height = 500, min_font_size = 10, background_color = 'white')

# %%
spam_wc = wc.generate(df[df['class_label'] == 1] ['transformed_text'].str.cat(sep = " "))

# %%
plt.imshow(spam_wc)

# %%
ham_wc = wc.generate(df[df['class_label'] == 0] ['transformed_text'].str.cat(sep = " "))

# %%
plt.imshow(ham_wc)

# %%
# top 30 words in ham and spam msgs

# %%
spam_corpus = []
for msg in df[df['class_label'] == 1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter
Counter(spam_corpus).most_common(30)
# Out:
# [('call', 320),
#  ('free', 191),
#  ('2', 155),
#  ('txt', 141),
#  ('text', 122),
#  ('u', 119),
#  ('ur', 119),
#  ('mobil', 114),
#  ('stop', 104),
#  ('repli', 103),
#  ('claim', 98),
#  ('4', 97),
#  ('prize', 82),
#  ('get', 74),
#  ('new', 64),
#  ('servic', 64),
#  ('tone', 63),
#  ('send', 60),
#  ('urgent', 57),
#  ('nokia', 57),
#  ('contact', 56),
#  ('award', 55),
#  ('phone', 52),
#  ('cash', 51),
#  ('pleas', 51),
#  ('week', 49),
#  ('win', 48),
#  ('c', 45),
#  ('collect', 45),
#  ('min', 45)]

# %%
ham_corpus = []
for msg in df[df['class_label'] == 0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
from collections import Counter
Counter(ham_corpus).most_common(30)
# Out:
# [('u', 883),
#  ('go', 404),
#  ('get', 349),
#  ('gt', 288),
#  ('lt', 287),
#  ('2', 284),
#  ('come', 275),
#  ('got', 236),
#  ('know', 236),
#  ('like', 234),
#  ('call', 233),
#  ('time', 219),
#  ('ok', 217),
#  ('love', 216),
#  ('good', 213),
#  ('want', 208),
#  ('ur', 197),
#  ('day', 190),
#  ('need', 170),
#  ('one', 165),
#  ('lor', 159),
#  ('4', 156),
#  ('home', 152),
#  ('think', 149),
#  ('see', 147),
#  ('take', 143),
#  ('still', 143),
#  ('da', 142),
#  ('tell', 133),
#  ('make', 129)]

# %% [markdown]
# ## Model Building

# %%
### Model Building
# Naive Bayes

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
vectorizer = TfidfVectorizer(max_features= 3000)

# %%
x = vectorizer.fit_transform(df['transformed_text']).toarray()

# %%
y = df['class_label'].values
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 2 )

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score

# %%
gnb = GaussianNB()
mnb =  MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(x_train, y_train)
y_pred1 = gnb.predict(x_test)
print(accuracy_score(y_test, y_pred1))
print(confusion_matrix(y_test, y_pred1))
print(precision_score(y_test, y_pred1))
# Out:
# 0.8694390715667312
# [[788 108]
#  [ 27 111]]
# 0.5068493150684932

# %%
mnb.fit(x_train, y_train)
y_pred2 = mnb.predict(x_test)
print(accuracy_score(y_test, y_pred2))
print(confusion_matrix(y_test, y_pred2))
print(precision_score(y_test, y_pred2))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(x_train, y_train)
y_pred3 = bnb.predict(x_test)
print(accuracy_score(y_test, y_pred3))
print(confusion_matrix(y_test, y_pred3))
print(precision_score(y_test, y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %%
## Multinomial naive bayes is best for given problem with 100% precision and 97% accuracy.

# %%
# !echo "# naive_bays" >> README.md

# %%
# !git init
# Out:
# 'git' is not recognized as an internal or external command,
# operable program or batch file.
